# %% [markdown]
# <a href="https://colab.research.google.com/github/sungmin0911/hackathon2025/blob/main/Your_Personal_Skin_Guide_Sungmin_Song.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gradio as gr

def get_recommendations(concerns):
    recommendations_db = {
        "acne": {
            "ingredients": [
                {"name": "Salicylic Acid", "desc": "Unclogs pores and reduces inflammation."},
                {"name": "Niacinamide", "desc": "Regulates oil production and minimizes redness."},
                {"name": "Benzoyl Peroxide", "desc": "Kills acne-causing bacteria effectively."}
            ],
            "products": ["CeraVe Acne Foaming Cream Cleanser", "The Ordinary Niacinamide 10% + Zinc 1%", "Paula's Choice 2% BHA Liquid Exfoliant"],
            "bad_habits": ["Touching your face frequently", "Picking at blemishes", "Not removing makeup before bed", "Using dirty pillowcases"],
            "how_to_fix": ["Wash your face twice daily with a gentle cleanser", "Change pillowcases every 2-3 days", "Use non-comedogenic products only", "Keep your hands away from your face"]
        },
        "dryness": {
            "ingredients": [
                {"name": "Hyaluronic Acid", "desc": "Attracts and retains moisture in the skin."},
                {"name": "Ceramides", "desc": "Helps restore the skin's natural barrier to lock in moisture."},
                {"name": "Glycerin", "desc": "A humectant that draws water into the skin."}
            ],
            "products": ["CeraVe Moisturizing Cream", "La Roche-Posay Cicaplast Balm B5", "Neutrogena Hydro Boost Water Gel"],
            "bad_habits": ["Taking very hot showers", "Over-washing your face", "Not drinking enough water", "Using harsh soaps"],
            "how_to_fix": ["Use lukewarm water when washing your face", "Apply moisturizer on damp skin", "Drink at least 8 glasses of water daily", "Use a humidifier in dry environments"]
        },
        "aging": {
            "ingredients": [
                {"name": "Retinol", "desc": "A powerhouse ingredient that boosts collagen and reduces fine lines."},
                {"name": "Vitamin C", "desc": "A potent antioxidant that brightens skin and protects from damage."},
                {"name": "Peptides", "desc": "Help stimulate collagen production for firmer skin."}
            ],
            "products": ["The Inkey List Retinol Serum", "SkinCeuticals C E Ferulic", "CeraVe Skin Renewing Retinol Serum"],
            "bad_habits": ["Skipping sunscreen", "Inadequate sleep", "Smoking", "Excessive sun exposure"],
            "how_to_fix": ["Apply SPF 30+ sunscreen daily, even indoors", "Get 7-9 hours of quality sleep", "Quit smoking and avoid secondhand smoke", "Wear protective clothing and seek shade"]
        },
        "sensitivity": {
            "ingredients": [
                {"name": "Centella Asiatica", "desc": "Known for its soothing and repairing properties."},
                {"name": "Colloidal Oatmeal", "desc": "Calms irritation and redness."},
                {"name": "Allantoin", "desc": "Soothes and protects sensitive skin."}
            ],
            "products": ["Aveeno Calm + Restore Oat Gel Moisturizer", "Etude House SoonJung 2x Barrier Intensive Cream", "La Roche-Posay Toleriane Double Repair Face Moisturizer"],
            "bad_habits": ["Using products with fragrance or alcohol", "Over-exfoliating", "Trying too many new products at once", "Using hot water on face"],
            "how_to_fix": ["Patch test new products before full application", "Stick to fragrance-free, hypoallergenic products", "Introduce new products one at a time", "Use gentle, non-foaming cleansers"]
        },
        "oily_skin": {
            "ingredients": [
                {"name": "Niacinamide", "desc": "Regulates sebum production without drying out skin."},
                {"name": "Salicylic Acid", "desc": "Controls oil and prevents clogged pores."},
                {"name": "Clay (Kaolin)", "desc": "Absorbs excess oil and mattifies skin."}
            ],
            "products": ["The Ordinary Niacinamide 10% + Zinc 1%", "Paula's Choice Pore Normalizing Cleanser", "Innisfree Super Volcanic Pore Clay Mask"],
            "bad_habits": ["Over-washing to remove oil (causes more oil production)", "Skipping moisturizer", "Using harsh, stripping products", "Not using sunscreen (thinking it will make skin oilier)"],
            "how_to_fix": ["Wash face only twice daily", "Use oil-free, gel-based moisturizers", "Choose lightweight, non-comedogenic sunscreen", "Use blotting papers instead of washing throughout the day"]
        },
        "dark_spots": {
            "ingredients": [
                {"name": "Vitamin C", "desc": "Brightens dark spots and evens skin tone."},
                {"name": "Niacinamide", "desc": "Fades hyperpigmentation and improves skin tone."},
                {"name": "Alpha Arbutin", "desc": "Gently lightens dark spots without irritation."},
                {"name": "Kojic Acid", "desc": "Inhibits melanin production to reduce dark spots."}
            ],
            "products": ["The Ordinary Alpha Arbutin 2% + HA", "CeraVe Vitamin C Serum", "Good Molecules Discoloration Correcting Serum"],
            "bad_habits": ["Not wearing sunscreen daily", "Picking at acne or skin", "Inconsistent skincare routine", "Using expired products"],
            "how_to_fix": ["Apply SPF 50+ daily to prevent further darkening", "Be patient - dark spots take 6-12 weeks to fade", "Use brightening products consistently morning and night", "Avoid picking or scratching skin"]
        },
        "large_pores": {
            "ingredients": [
                {"name": "Niacinamide", "desc": "Minimizes the appearance of pores over time."},
                {"name": "Salicylic Acid", "desc": "Unclogs and tightens pores."},
                {"name": "Retinol", "desc": "Increases cell turnover and refines pore size."}
            ],
            "products": ["Paula's Choice 2% BHA Liquid Exfoliant", "The Ordinary Niacinamide 10% + Zinc 1%", "CeraVe Resurfacing Retinol Serum"],
            "bad_habits": ["Not removing makeup properly", "Sleeping with makeup on", "Using pore strips (can enlarge pores)", "Skipping exfoliation"],
            "how_to_fix": ["Double cleanse to remove all makeup and sunscreen", "Exfoliate 2-3 times per week", "Use a clay mask weekly to deep clean pores", "Always remove makeup before bed"]
        },
        "dullness": {
            "ingredients": [
                {"name": "Vitamin C", "desc": "Brightens and revitalizes dull, tired skin."},
                {"name": "AHA (Glycolic/Lactic Acid)", "desc": "Exfoliates dead skin cells for a radiant glow."},
                {"name": "Niacinamide", "desc": "Improves overall skin radiance and texture."}
            ],
            "products": ["The Ordinary Vitamin C Suspension 23% + HA Spheres 2%", "CeraVe Resurfacing Retinol Serum", "Glow Recipe Watermelon Glow Niacinamide Dew Drops"],
            "bad_habits": ["Not exfoliating regularly", "Poor sleep habits", "Dehydration", "High stress levels"],
            "how_to_fix": ["Exfoliate 2-3 times weekly to remove dead skin", "Get adequate sleep (7-9 hours)", "Stay hydrated throughout the day", "Exercise regularly to boost circulation"]
        },
        "redness": {
            "ingredients": [
                {"name": "Centella Asiatica", "desc": "Calms inflammation and reduces redness."},
                {"name": "Azelaic Acid", "desc": "Reduces redness and evens skin tone."},
                {"name": "Green Tea Extract", "desc": "Anti-inflammatory properties soothe irritated skin."},
                {"name": "Niacinamide", "desc": "Strengthens skin barrier and reduces redness."}
            ],
            "products": ["The Ordinary Azelaic Acid Suspension 10%", "La Roche-Posay Cicaplast Balm B5", "COSRX Centella Water Alcohol-Free Toner"],
            "bad_habits": ["Using hot water on face", "Over-exfoliating", "Consuming spicy foods and alcohol", "Exposing skin to extreme temperatures"],
            "how_to_fix": ["Use lukewarm water only", "Avoid triggers like spicy food and alcohol", "Protect skin from wind and extreme cold", "Use a gentle, fragrance-free routine"]
        },
        "uneven_texture": {
            "ingredients": [
                {"name": "AHA (Glycolic Acid)", "desc": "Smooths rough texture and refines skin surface."},
                {"name": "BHA (Salicylic Acid)", "desc": "Penetrates pores to smooth from within."},
                {"name": "Retinol", "desc": "Accelerates cell turnover for smoother skin."}
            ],
            "products": ["Paula's Choice 8% AHA Gel Exfoliant", "The Ordinary Lactic Acid 10% + HA", "CeraVe Skin Renewing Retinol Serum"],
            "bad_habits": ["Not exfoliating regularly", "Using harsh scrubs", "Inconsistent skincare routine", "Touching face with dirty hands"],
            "how_to_fix": ["Exfoliate 2-3 times per week with chemical exfoliants", "Avoid physical scrubs that can damage skin", "Maintain a consistent routine", "Keep hands clean and away from face"]
        }
    }

    if not concerns:
        return "<h3 style='color: red;'>Please go back and select at least one concern.</h3>"

    result_html = ""
    for concern in concerns:
        if concern in recommendations_db:
            details = recommendations_db[concern]
            result_html += f"<div style='margin-bottom: 2.5em; padding: 1em; border-radius: 8px; border: 1px solid #e0e0e0;'>"
            result_html += f"<h2>Recommendations for: <span style='color: #0d9488;'>{concern.replace('_', ' ').title()}</span></h2>"

            result_html += "<h3>Key Ingredients</h3><ul>"
            for ingredient in details["ingredients"]:
                result_html += f"<li><strong>{ingredient['name']}:</strong> {ingredient['desc']}</li>"
            result_html += "</ul>"

            result_html += "<h3>Example Products</h3><ul>"
            for product in details["products"]:
                result_html += f"<li>{product}</li>"
            result_html += "</ul>"

            result_html += "<h3>Habits to Avoid</h3><ul>"
            for habit in details["bad_habits"]:
                result_html += f"<li>{habit}</li>"
            result_html += "</ul>"

            result_html += "<h3>How to Fix</h3><ul>"
            for fix in details["how_to_fix"]:
                result_html += f"<li>{fix}</li>"
            result_html += "</ul>"

            result_html += f"</div>"

    return result_html

# --- UI Definition and Flow ---

# Define a theme for the app
theme = gr.themes.Soft(primary_hue="teal", secondary_hue="orange")
custom_css = """
.gradio-container {
    max-width: 700px !important;
    margin: auto !important;
}

/* Enhanced View Styles - 1.08x bigger */
body.enhanced-view h1,
.enhanced-view h1 {
    font-size: 1.08em !important;
}

body.enhanced-view h2,
.enhanced-view h2 {
    font-size: 1.08em !important;
}

body.enhanced-view h3,
.enhanced-view h3 {
    font-size: 1.08em !important;
}

body.enhanced-view p,
body.enhanced-view li,
body.enhanced-view label,
body.enhanced-view span,
body.enhanced-view div,
.enhanced-view p,
.enhanced-view li,
.enhanced-view label,
.enhanced-view span,
.enhanced-view div {
    font-size: 1.08em !important;
    line-height: 1.5 !important;
}

body.enhanced-view button,
.enhanced-view button {
    font-size: 1.08em !important;
    padding: 12px 20px !important;
    min-height: 50px !important;
}

body.enhanced-view input,
body.enhanced-view textarea,
.enhanced-view input,
.enhanced-view textarea {
    font-size: 1.08em !important;
    padding: 10px !important;
}
"""

with gr.Blocks(theme=theme, css= custom_css) as demo:

    ui_mode = gr.State('younger')
    mode_script = gr.HTML(visible=False) # Define mode_script as a Gradio HTML component


    with gr.Column(visible=True) as start_page:
        gr.HTML("""
            <div style='text-align: center;'>
                <h1 style='font-size: 3em; margin-bottom: 0.2em; color: #0d9488;'>Your Personal Skin Health Guide</h1>
                <p style='font-style: italic; color: #f59e0b; font-size: 1.2em;'>Your Personal Skin Health Companion</p>
            </div>
        """)
        gr.Markdown("---")
        gr.Markdown("### Choose Your Preferences")
        with gr.Row():

            younger_btn = gr.Button("👤\nStandard View", variant="secondary", scale=1)
            older_btn = gr.Button("👵\nEnhanced View (Bigger Text)", variant="secondary", scale=1)

    with gr.Column(visible=False) as auth_page:
        gr.Markdown("# Welcome!")
        gr.Markdown("Sign in to save your preferences or continue as a guest.")
        signin_nav_btn = gr.Button("Sign In", variant="primary")
        signup_nav_btn = gr.Button("Sign Up", variant="primary")
        guest_btn = gr.Button("Continue as Guest", variant="secondary")
        back_to_start_btn = gr.Button("⬅️ Back to Start")

    with gr.Column(visible=False) as signin_page:
        gr.Markdown("## Welcome Back!")
        email_signin = gr.Textbox(label="Email", placeholder="you@example.com")
        password_signin = gr.Textbox(label="Password", type="password")
        signin_submit_btn = gr.Button("Sign In", variant="primary")
        back_to_auth_btn_1 = gr.Button("⬅️ Back")

    with gr.Column(visible=False) as signup_page:
        gr.Markdown("## Create Your Account")
        email_signup = gr.Textbox(label="Email", placeholder="you@example.com")
        password_signup = gr.Textbox(label="Password", type="password")
        signup_submit_btn = gr.Button("Sign Up", variant="primary")
        back_to_auth_btn_2 = gr.Button("⬅️ Back")

    with gr.Column(visible=False) as concerns_page:
        gr.Markdown("## What are your skin concerns?\nSelect all that apply.")
        concerns_checkbox = gr.CheckboxGroup(choices=[
        ("☄️ Acne", "acne"),
        ("💧 Dryness", "dryness"),
        ("⏳ Aging", "aging"),
        ("🧴 Sensitivity", "sensitivity"),
        ("✨ Oily Skin", "oily_skin"),
        ("🌑 Dark Spots", "dark_spots"),
        ("⭕ Large Pores", "large_pores"),
        ("😴 Dullness", "dullness"),
        ("🔥 Redness", "redness"),
        ("🪨 Uneven Texture", "uneven_texture")
    ],
        label="Skin Concerns"
        )
        get_recs_btn = gr.Button("Get Recommendations", variant="primary")
        back_to_auth_from_concerns_btn = gr.Button("⬅️ Back")

    with gr.Column(visible=False) as results_page:
        gr.Markdown("## Your Personalized Skincare Plan")
        recommendations_output = gr.HTML()
        back_to_concerns_btn = gr.Button("⬅️ Back to Selections")
    def apply_mode_styling(mode):
      if mode == 'older':
          script = """
          <script>
          (function() {
              setTimeout(function() {
                  // Apply to body
                  document.body.classList.add('enhanced-view');

                  // Apply to gradio-app
                  const gradioApp = document.querySelector('gradio-app');
                  if (gradioApp) gradioApp.classList.add('enhanced-view');

                  // Apply to main container
                  const containers = document.querySelectorAll('.gradio-container, .contain, .app, .wrap');
                  containers.forEach(el => el.classList.add('enhanced-view'));

                  console.log('Enhanced view activated');
              }, 50);
          })();
          </script>
          """
      else:
          script = """
          <script>
          (function() {
              setTimeout(function() {
                  document.body.classList.remove('enhanced-view');
                  const gradioApp = document.querySelector('gradio-app');
                  if (gradioApp) gradioApp.classList.remove('enhanced-view');

                  const containers = document.querySelectorAll('.gradio-container, .contain, .app, .wrap');
                  containers.forEach(el => el.classList.remove('enhanced-view'));

                  console.log('Standard view deactivated');
              }, 50);
          })();
          </script>
          """
      return script


    def go_to_auth(mode):
        return (
            mode,
            apply_mode_styling(mode),
            gr.update(visible=False),
            gr.update(visible=True)
        )

    def go_to_signin():
        return (gr.update(visible=False), gr.update(visible=True))

    def go_to_signup():
        return (gr.update(visible=False), gr.update(visible=True))

    def go_to_concerns():
        return (
            gr.update(visible=False),
            gr.update(visible=False),
            gr.update(visible=False),
            gr.update(visible=True)
        )

    def show_results(concerns):
        recommendation_html = get_recommendations(concerns)
        return (
            gr.update(visible=False),
            gr.update(visible=True),
            gr.update(value=recommendation_html)
        )

    def go_back_to_start(mode):
        return (
            apply_mode_styling(mode),
            gr.update(visible=False),
            gr.update(visible=True)
        )

    def go_back_to_auth():
        return (
            gr.update(visible=False),
            gr.update(visible=False),
            gr.update(visible=False),
            gr.update(visible=True)
        )

    def go_back_to_concerns():
        return (gr.update(visible=False), gr.update(visible=True))

    younger_btn.click(
    fn=lambda: go_to_auth('younger'),
    inputs=None,
    outputs=[ui_mode, mode_script, start_page, auth_page],
    js="""
    () => {
        document.body.classList.remove('enhanced-view');
        const containers = document.querySelectorAll('.gradio-container, .contain, .app, .wrap');
        containers.forEach(el => el.classList.remove('enhanced-view'));
        console.log('Standard view activated');
    }
    """
    )

    older_btn.click(
        fn=lambda: go_to_auth('older'),
        inputs=None,
        outputs=[ui_mode, mode_script, start_page, auth_page],
        js="""
        () => {
            document.body.classList.add('enhanced-view');
            const containers = document.querySelectorAll('.gradio-container, .contain, .app, .wrap');
            containers.forEach(el => el.classList.add('enhanced-view'));
            console.log('Enhanced view activated');
        }
        """
    )


    signin_nav_btn.click(fn=go_to_signin, inputs=None, outputs=[auth_page, signin_page])
    signup_nav_btn.click(fn=go_to_signup, inputs=None, outputs=[auth_page, signup_page])
    guest_btn.click(fn=go_to_concerns, inputs=None, outputs=[auth_page, signin_page, signup_page, concerns_page])
    back_to_start_btn.click(
        fn=lambda mode: go_back_to_start(mode),
        inputs=[ui_mode],
        outputs=[mode_script, auth_page, start_page]
    )

    signin_submit_btn.click(fn=go_to_concerns, inputs=None, outputs=[auth_page, signin_page, signup_page, concerns_page])
    signup_submit_btn.click(fn=go_to_concerns, inputs=None, outputs=[auth_page, signin_page, signup_page, concerns_page])
    back_to_auth_btn_1.click(fn=go_back_to_auth, inputs=None, outputs=[signin_page, signup_page, concerns_page, auth_page])
    back_to_auth_btn_2.click(fn=go_back_to_auth, inputs=None, outputs=[signin_page, signup_page, concerns_page, auth_page])


    get_recs_btn.click(fn=show_results, inputs=[concerns_checkbox], outputs=[concerns_page, results_page, recommendations_output])
    back_to_auth_from_concerns_btn.click(fn=go_back_to_auth, inputs=None, outputs=[signin_page, signup_page, concerns_page, auth_page])


    back_to_concerns_btn.click(fn=go_back_to_concerns, inputs=None, outputs=[results_page, concerns_page])


if __name__ == "__main__":
    demo.launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://a8fd00f89a5662a81a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a8fd00f89a5662a81a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7861 <> https://a8fd00f89a5662a81a.gradio.live
